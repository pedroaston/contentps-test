# %% [markdown]
# ## Metric Results - 18 nodes
# Here we show graphics relative to CPU, memory and event latency metrics relative of our pubsub middleware in different scenarios and of 18 peers. This results were collected from a testground environment:
# - Executed on: ubuntu VM with 12GB RAM and 4 cores.
# - Latency between peers: 10ms
#
# ### Normal Scenario
# Here things are chill.

# %%
import process_run

process_run.plot_memory_metric("normal")
process_run.plot_cpu_metric("normal")
process_run.plot_latency_metric("normal")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-4f1ef0277f88> in <module>
#       1 import process_run
#       2
# ----> 3 process_run.plot_memory_metric("normal")
#       4 process_run.plot_cpu_metric("normal")
#       5 process_run.plot_latency_metric("normal")
#
# ~/testground/plans/contentps-test/scripts/process_run.py in plot_memory_metric(scenario)
#     118
#     119     labels = ['FastDelivery', 'Base-Unreliable', 'Base-Reliable', 'Redirect-Unreliable', 'Redirect-Reliable']
# --> 120     mean_values = [fast_res['Memory used - FastDelivery/mean'], scout_res_BU['Memory used - ScoutSubs '+scenario+'BU/mean'],
#     121      scout_res_BR['Memory used - ScoutSubs '+scenario+'BR/mean'], scout_res_RU['Memory used - ScoutSubs '+scenario+'RU/mean'],
#     122      scout_res_RR['Memory used - ScoutSubs '+scenario+'RR/mean']]
#
# KeyError: 'Memory used - FastDelivery/mean'

# %% [markdown]
# ### Subscription Burst Scenario
# Here at the same time that events are being published, all subscribers are floding the middleware with new subscriptions, that are irrelevant to the events' forwarding, but will load the system.

# %%
import process_run

process_run.plot_memory_metric("subBurst")
process_run.plot_cpu_metric("subBurst")
process_run.plot_latency_metric("subBurst")

# %% [markdown]
# ### Event Burst Scenario
# Here the number of events published is significantly bigger. This way analyze how the system behaves in a scenario like this one.

# %%
import process_run

process_run.plot_memory_metric("eventBurst")
process_run.plot_cpu_metric("eventBurst")
process_run.plot_latency_metric("eventBurst")

# %% [markdown]
# ### Fault Tolerance Scenario
# Here we have a scenario similar to the normal one, but this time one group of subs crashes after the subscription routine.

# %%
import process_run

process_run.plot_memory_metric("fault")
process_run.plot_cpu_metric("fault")
process_run.plot_latency_metric("fault")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-c2c305727c73> in <module>
#       1 import process_run
#       2
# ----> 3 process_run.plot_memory_metric("fault")
#       4 process_run.plot_cpu_metric("fault")
#       5 process_run.plot_latency_metric("fault")
#
# ~/testground/plans/contentps-test/scripts/process_run.py in plot_memory_metric(scenario)
#     133
#     134     labels = ['FastDelivery', 'Base-Unreliable', 'Base-Reliable', 'Redirect-Unreliable', 'Redirect-Reliable']
# --> 135     mean_values = [fast_res['Memory used - FastDelivery/mean'], scout_res_BU['Memory used - ScoutSubs '+scenario+'BU/mean'],
#     136      scout_res_BR['Memory used - ScoutSubs '+scenario+'BR/mean'], scout_res_RU['Memory used - ScoutSubs '+scenario+'RU/mean'],
#     137      scout_res_RR['Memory used - ScoutSubs '+scenario+'RR/mean']]
#
# KeyError: 'Memory used - FastDelivery/mean'

# %%
import process_run

res = process_run.metric_summary("FastDelivery")
print(res)
# Out:
# {'CPU used - FastDelivery/max': 0, 'CPU used - FastDelivery/all': [0.5299999999999727, 0.5199999999999818, 0.5499999999999545, 0.57000000000005, 0.5299999999999727, 0.57000000000005, 0.57000000000005, 0.5299999999999727, 0.5199999999999818, 0.5099999999999909, 0.5399999999999636, 0.5499999999999545, 0.5399999999999636, 0.5099999999999909, 0.5800000000000409, 0.5399999999999636, 0.5399999999999636, 0.5099999999999909], 'Memory used - FastDelivery/max': 0, 'Memory used - FastDelivery/all': [29.16015625, 29.8828125, 29.1875, 28.859375, 29.39453125, 29.54296875, 29.16015625, 29.9453125, 29.875, 28.38671875, 29.5390625, 29.84765625, 29.91015625, 28.484375, 29.16796875, 29.53125, 29.91015625, 28.33203125], 'Event Latency - FastDelivery/max': 0, 'Event Latency - FastDelivery/all': [53, 106, 107, 60, 106, 54, 107, 61, 117, 53, 54, 52, 107, 52, 117, 60, 107, 54, 105, 105, 105, 107], 'Sub Latency - FastDelivery/max': 0, 'Sub Latency - FastDelivery/all': [128, 145, 192, 255, 209, 128, 128, 190, 126, 126, 133, 191, 228, 129, 243, 193, 192, 127, 196, 200, 245, 130], '# Events Missing - FastDelivery': 9, '# Events Duplicated - FastDelivery': 0, 'CPU used - FastDelivery': 0.5099999999999909, 'Memory used - FastDelivery': 28.33203125, 'Event Latency - FastDelivery': 107, 'Sub Latency - FastDelivery': 130, 'CPU used - FastDelivery/mean': 0.5394444444444338, 'Memory used - FastDelivery/mean': 29.33984375, 'Event Latency - FastDelivery/mean': 84.04545454545455, 'Sub Latency - FastDelivery/mean': 174.27272727272728}

# %%
import process_run

process_run.plot_memory_metric("normal")
process_run.plot_cpu_metric("normal")
process_run.plot_latency_metric("normal")
process_run.boxplot_latency("normal")
process_run.plot_correctness_metrics("normal")
