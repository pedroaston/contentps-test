# %% [markdown]
# ### Metric Results - Normal Scenario
# Here we have the graphics relative to CPU, memory and event latency!

# %%
import process_run

process_run.plot_memory_metric("normal")
process_run.plot_cpu_metric("normal")
process_run.plot_latency_metric("normal")
